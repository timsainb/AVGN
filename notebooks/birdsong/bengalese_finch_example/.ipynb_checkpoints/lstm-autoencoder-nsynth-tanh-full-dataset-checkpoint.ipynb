# %%
# %load_ext autoreload
# %autoreload 2

# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display
from tqdm.autonotebook import tqdm

import numpy as np
import tensorflow as tf
from avgn.utils.paths import DATA_DIR

from avgn.datasets.nsynth import HParams, NSynthDataset
from avgn.networks.ae import AE
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ### define hparams

# %%
hparams = HParams(  
    batch_size = 32,
    win_length = 512,
    n_fft = 1024,
    hop_length=400,
    ref_level_db = 20,
    min_level_db = -100,
    power = 1, # for spectral inversion
    griffin_lim_iters = 50,
    spectrogram = True,
    #pad=True,
    mel = True,
    mfcc = False,
    mel_matrix_dict = {
        'num_mel_bins': 32,
        'num_spectrogram_bins' : 513,
        'sample_rate' : 16000,
        'lower_edge_hertz':125.0,
        'upper_edge_hertz':3800.0,
    }
)

# %% [markdown]
# ### Get dataset

# %%
training_tfrecords = list((DATA_DIR / "tensorflow_datasets"/"nsynth").glob('**/*train.tfrecord*'))

# %%
dset = NSynthDataset([str(i) for i in training_tfrecords], hparams, num_parallel_calls = 24)

# %%
exs = iter(dset.dataset_batch)
ex = next(exs)
spec_ex = ex['spectrogram'].numpy()[0]

# %%
np.shape(spec_ex)
# Out:
# (160, 32)

# %%
example_data = tf.expand_dims(next(iter(dset.dataset_batch))['spectrogram'], axis=3)

# %%
fig, ax = plt.subplots(ncols=1, figsize=(12,6))
cset1 = ax.matshow(np.squeeze(example_data.numpy()[0]).T, aspect='auto', origin='lower')
fig.colorbar(cset1, ax=ax)

# %%
list(example_data.shape)
# Out:
# [32, 160, 32, 1]

# %% [markdown]
# ### Make network

# %%
from tensorflow.keras.layers import (
    RepeatVector,
    Dense,
    TimeDistributed,
    Conv1D,
    Conv2D,
    Reshape,
    Bidirectional
)  # , LSTM
from tensorflow.python.keras.layers.recurrent import UnifiedLSTM as LSTM
#from tensorflow.keras.layers import CuDNNLSTM as LSTM

# %%
seq_len = 10 # the number of items in the sequence, which is determined by convolutional downsampling
spec_chans_last = 4

# %%
enc = [
        tf.keras.layers.Conv2D(
            filters=32,
            kernel_size=6,
            strides=(4, 2),
            activation="relu",
            padding="same",
        ),
        tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=3,
            strides=(2, 2),
            activation="relu",
            padding="same",
        ),
        tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=3,
            strides=(2, 2),
            activation="relu",
            padding="same",
        ),
        Reshape(target_shape=(seq_len, spec_chans_last*128)),
        Bidirectional(LSTM(units=512, activation="relu")),
        #Dense(units=512)
    ]
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0507 09:51:55.074316 140428941350656 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7fb774218208>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# W0507 09:51:55.082494 140428941350656 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7fb774218908>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %%
dec = [
        #Dense(units=512),
        RepeatVector(seq_len),
        Bidirectional(LSTM(units=512, activation="relu", return_sequences=True)),
        TimeDistributed(Dense(spec_chans_last * 128)), # features times the number of filters
        Reshape(target_shape=(seq_len, spec_chans_last, 128)),
        tf.keras.layers.Conv2DTranspose(
            filters=128,
            kernel_size=6,
            strides=(4, 2),
            padding="SAME",
            activation="relu",
        ),
        tf.keras.layers.Conv2DTranspose(
            filters=64,
            kernel_size=3,
            strides=(2, 2),
            padding="SAME",
            activation="relu",
        ),
        tf.keras.layers.Conv2DTranspose(
            filters=32,
            kernel_size=3,
            strides=(2, 2),
            padding="SAME",
            activation="relu",
        ),
        tf.keras.layers.Conv2DTranspose(
            filters=1,
            kernel_size=3,
            strides=(1, 1),
            padding="SAME",
            activation="tanh",
        ),
        Reshape(target_shape=(160, 32, 1)),
    ]
# Out:
# W0507 09:51:55.187127 140428941350656 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7fb7741c21d0>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# W0507 09:51:55.190470 140428941350656 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7fb7741c2860>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %%
optimizer = tf.keras.optimizers.Adam(1e-3)

# %%
model = AE(
    enc = enc,
    dec = dec,
    optimizer = optimizer
)

# %%
ex_z = model.encode(example_data)
print(ex_z.shape)
# Out:
# (32, 1024)

# %%
np.max((ex_z.numpy()))
# Out:
# 0.041526623

# %%
ex_x = model.decode(ex_z)
print(ex_x.shape)
# Out:
# (32, 160, 32, 1)

# %%
examp = next(iter(dset.dataset_batch))['spectrogram']

# %%
example_loss = []

# %%
for epoch in range(1000): 
    txi = 0
    for train_x in tqdm(dset.dataset_batch):
        gradients = model.compute_gradients(tf.expand_dims(train_x['spectrogram'], axis=3))
        model.optimizer.apply_gradients(zip(gradients, model.trainable_variables)) 
        txi +=1
        if (txi % 100 == 0): 
            if (txi % 1000 == 0) & (epoch !=0):
                display.clear_output(wait=False)
                plt.loglog(example_loss)
                plt.show()
            example_loss.append(model.compute_loss(example_data).numpy())
            print(example_loss[-1])
            recon = model.decode(model.encode(example_data))
            nex = 6
            fig, axs = plt.subplots(nrows =2,ncols = nex, figsize=(nex*4,3*2))
            for nix in range(nex):
                axs[0, nix].matshow(np.squeeze(example_data.numpy()[nix]).T, vmin=0, vmax=1, aspect='auto', origin='lower')
                axs[1, nix].matshow(np.squeeze(recon.numpy()[nix]).T, vmin=0, vmax=1, aspect='auto', origin='lower')
            plt.show()
# Out:
# 0.0005292964
# 0.0005297625
# 0.0005466788
# 0.00054408674
# 0.0005377733
# 0.00053210196
# 0.0005325765
# 0.00055017415
# 0.00053341076
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-5df047311538> in <module>
#       3     for train_x in tqdm(dset.dataset_batch):
#       4         gradients = model.compute_gradients(tf.expand_dims(train_x['spectrogram'], axis=3))
# ----> 5         model.optimizer.apply_gradients(zip(gradients, model.trainable_variables))
#       6         txi +=1
#       7         if (txi % 100 == 0):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name)
#     404
#     405     return distribute_ctx.get_replica_context().merge_call(
# --> 406         self._distributed_apply, args=(grads_and_vars,), kwargs={"name": name})
#     407
#     408   def _distributed_apply(self, distribution, grads_and_vars, name):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in merge_call(self, merge_fn, args, kwargs)
#    1373     if kwargs is None:
#    1374       kwargs = {}
# -> 1375     return self._merge_call(merge_fn, args, kwargs)
#    1376
#    1377   def _merge_call(self, merge_fn, args, kwargs):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _merge_call(self, merge_fn, args, kwargs)
#    1380         distribution_strategy_context._CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    1381     try:
# -> 1382       return merge_fn(self._strategy, *args, **kwargs)
#    1383     finally:
#    1384       _pop_per_thread_mode()
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in _distributed_apply(self, distribution, grads_and_vars, name)
#     438           update_ops.extend(
#     439               distribution.extended.update(
# --> 440                   var, apply_grad_to_update_var, args=(grad,), group=False))
#     441       with ops.control_dependencies(update_ops):
#     442         apply_updates = self._iterations.assign_add(1)
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in update(self, var, fn, args, kwargs, group)
#    1173     if kwargs is None:
#    1174       kwargs = {}
# -> 1175     return self._update(var, fn, args, kwargs, group)
#    1176
#    1177   def _update(self, var, fn, args, kwargs, group):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _update(self, var, fn, args, kwargs, group)
#    1544     # The implementations of _update() and _update_non_slot() are identical
#    1545     # except _update() passes `var` as the first argument to `fn()`.
# -> 1546     return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#    1547
#    1548   def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/distribute/distribute_lib.py in _update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    1550     # once that value is used for something.
#    1551     with ops.colocate_with(colocate_with), UpdateContext(colocate_with):
# -> 1552       result = fn(*args, **kwargs)
#    1553       if should_group:
#    1554         return result
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_grad_to_update_var(var, grad)
#     423         return self._resource_apply_sparse_duplicate_indices(
#     424             grad.values, var, grad.indices)
# --> 425       update_op = self._resource_apply_dense(grad, var)
#     426       if var.constraint is not None:
#     427         with ops.control_dependencies([update_op]):
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/adam.py in _resource_apply_dense(self, grad, var)
#     174     local_step = math_ops.cast(self.iterations + 1, var_dtype)
#     175     beta_1_power = math_ops.pow(beta_1_t, local_step)
# --> 176     beta_2_power = math_ops.pow(beta_2_t, local_step)
#     177     if not self.amsgrad:
#     178       return training_ops.resource_apply_adam(
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in pow(x, y, name)
#     426   """
#     427   with ops.name_scope(name, "Pow", [x]) as name:
# --> 428     return gen_math_ops._pow(x, y, name=name)
#     429
#     430
#
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _pow(x, y, name)
#    6791       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#    6792         _ctx._context_handle, _ctx._thread_local_data.device_name, "Pow",
# -> 6793         name, _ctx._post_execution_callbacks, x, y)
#    6794       return _result
#    6795     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
plt.loglog(example_loss)

# %%
example_loss[100]
# Out:
# 0.0012546552

# %%
np.mean(example_loss[-10:])
# 0.0007693957

# %%
plt.plot(np.mean(example_data.numpy()[0], axis=0))
plt.plot(np.mean(recon.numpy()[0], axis=0))

# %%
plt.plot(np.mean(example_data.numpy()[0], axis=1))
plt.plot(np.mean(recon.numpy()[0], axis=1))
